# %% [markdown]
# # MAP for downstream classification tasks

# %% [markdown]
# ## Gene Expression

# %% [markdown]
# ![gene_expression.png](attachment:gene_expression.png)

# %% [markdown]
# ## Promoter-Enhancer Interactions

# %% [markdown]
# ![map_pe.png](attachment:map_pe.png)

# %% [markdown]
# ## Frequently Interacting Regions (FIREs)

# %% [markdown]
# ![map_fire.png](attachment:map_fire.png)

# %% [markdown]
# ## Replication Timing

# %% [markdown]
# ![map_rep.png](attachment:map_rep.png)
